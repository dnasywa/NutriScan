# %% [markdown]
# <a href="https://colab.research.google.com/github/dnasywa/NutriScan/blob/main/capstone_RGB_model_and_recomendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# ## Overview

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# dataset Info
base_dir = '/content/drive/MyDrive/capstone/dataset/lettuce'
class_names = ['FN', '-N', '-P', '-K']

# %% [markdown]
# ## Split

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# %%
train_dir = base_dir + "/train"
validation_dir = base_dir + "/validation"
test_dir = base_dir + "/test"

# %%
# create the directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(validation_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# %%
for class_name in class_names:
    folder_path = os.path.join(base_dir, class_name)

    if os.path.isdir(folder_path):
        images = os.listdir(folder_path)

        # split images into train 0.6 and remaining
        train_images, remaining_images = train_test_split(images, test_size=0.4, random_state=42)

        # split remaining images into validation 0.25 and test 0.15
        validation_images, test_images = train_test_split(remaining_images, test_size=0.375, random_state=42)
            
        # copy TRAIN images to the TRAIN directory
        for image in train_images:
            src = os.path.join(folder_path, image)
            dst = os.path.join(train_dir, class_name, image)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy2(src, dst)
            
        # copy VALIDATION images to the VALIDATION directory
        for image in validation_images:
            src = os.path.join(folder_path, image)
            dst = os.path.join(validation_dir, class_name, image)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy2(src, dst)
            
        # copy TEST images to the TEST directory
        for image in test_images:
            src = os.path.join(folder_path, image)
            dst = os.path.join(test_dir, class_name, image)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy2(src, dst)

# %% [markdown]
# ## Augmentation

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img_width, img_height = 224, 224 # Image size to be used

# %%
train_datagen = ImageDataGenerator(
    rescale = 1/255.0,
    rotation_range = 40,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest',
    brightness_range = [0.8, 1.2]
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (img_width, img_height),
    batch_size = 32,
    class_mode ='categorical'
)
# Out:
# Found 144 images belonging to 4 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 60 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 40 images belonging to 4 classes.

# %% [markdown]
# # Feature Extraction

# %%
import cv2
import random
import numpy as np

from collections import Counter
from sklearn.cluster import KMeans
from sklearn.feature_extraction import image

# %matplotlib inline

# %% [markdown]
# ## RGB Extraction

# %%
# convert the hex values
def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %%
# accept both file paths and numpy array
def get_image(image):
    if isinstance(image, str):  # when image is a file path
        image = cv2.imread(image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
def get_colors(image, number_of_colors):

    modified_image = cv2.resize(image, (img_width, img_height), interpolation=cv2.INTER_AREA)
    modified_image = modified_image.reshape(modified_image.shape[0] * modified_image.shape[1], 3)

    # warning: default value for n_init will change from 10 to 'auto' in scikit-learn version 1.4
    clf = KMeans(n_clusters=number_of_colors, n_init=10)
    labels = clf.fit_predict(modified_image)

    counts = Counter(labels)
    center_colors = clf.cluster_centers_

    # ordered colors by iterating through the keys
    ordered_colors = [center_colors[i] / 255 for i in counts.keys()]
    rgb_colors = [ordered_colors[i] * 255 for i in counts.keys()]

    return rgb_colors # a list of features

# %%
# check the RGB arrays returns
for i in range(3):
    # select a random folder from TRAIN dataset
    folder = random.choice(os.listdir(train_dir))
    folder_path = os.path.join(train_dir, folder)
    image_files = os.listdir(folder_path)

     # select a random image from the folder
    image_file = random.choice(image_files)
    image_path = os.path.join(folder_path, image_file)

    # return the RGB arrays
    print(image_path)
    print(get_colors(get_image(image_path), 3))
# Out:
# /content/drive/MyDrive/capstone/dataset/lettuce/train/-N/-N (49).png
# [array([236.86864656, 238.62169201, 236.71410569]), array([ 89.56459897, 124.78411695,   6.62386409]), array([168.55486693, 187.86197594,  38.43711265])]
# /content/drive/MyDrive/capstone/dataset/lettuce/train/-N/-N (46).png
# [array([183.3895703 , 212.18498123,  20.5547768 ]), array([104.86310667, 135.14489691,  45.14822641]), array([240.70314092, 243.2295663 , 243.46356266])]
# /content/drive/MyDrive/capstone/dataset/lettuce/train/-P/-P (21).png
# [array([112.31867081, 127.09124233,  71.25954259]), array([198.23143064, 216.8089713 , 224.87568632]), array([59.83552585, 52.55354972, 33.55665976])]

# %% [markdown]
# ## Extract from Directories

# %%
# lists and array to store the features and labels
train_features = []
train_labels = np.empty((0,), dtype=str)

validation_features = []
validation_labels = np.empty((0,), dtype=str)

test_features = []
test_labels = np.empty((0,), dtype=str)

# %%
# iterate over the TRAIN directory
for folder_name in os.listdir(train_dir):
    folder_path = os.path.join(train_dir, folder_name)
    
    # extract if the item is a directory
    if os.path.isdir(folder_path):
        # iterate over the files in the current dir
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            
            # check if the item is a file
            if os.path.isfile(file_path):
                # extract features from the image
                image = get_image(file_path)
                preprocessed_image = train_datagen.random_transform(image)
                features = get_colors(preprocessed_image, 3)

                # append the features to the train_features list
                train_features.append(features)
                train_labels = np.concatenate((train_labels, np.array([folder_name])), axis=0)

# %%
# convert to a numpy array
train_features = np.array(train_features)

# %%
# print the shape of the TRAIN arrays
print("Train Features Shape:", train_features.shape)
print("Train Labels Shape:", train_labels.shape)
# Out:
# Train Features Shape: (144, 3, 3)
# Train Labels Shape: (144,)

# %%
# iterate over the VALIDATION directory
for folder_name in os.listdir(validation_dir):
    folder_path = os.path.join(validation_dir, folder_name)
    
    # check if the item is a directory
    if os.path.isdir(folder_path):
        # iterate over the files in the current dir
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            
            # check if the item is a file
            if os.path.isfile(file_path):
                # extract features from the image
                image = get_image(file_path)
                preprocessed_image = validation_datagen.random_transform(image)
                features = get_colors(preprocessed_image, 3)

                # append the features to the validation_features list
                validation_features.append(features)
                validation_labels = np.concatenate((validation_labels, np.array([folder_name])), axis=0)

# %%
# convert to a numpy array
validation_features = np.array(validation_features)

# %%
# print the shape of the VALIDATION arrays
print("Validation Features Shape:", validation_features.shape)
print("Validation Labels Shape:", validation_labels.shape)
# Out:
# Validation Features Shape: (60, 3, 3)
# Validation Labels Shape: (60,)

# %%
# iterate over the TEST directory
for folder_name in os.listdir(test_dir):
    folder_path = os.path.join(test_dir, folder_name)
    
    # check if the item is a directory
    if os.path.isdir(folder_path):
        # iterate over the files in the current dir
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            
            # check if the item is a file
            if os.path.isfile(file_path):
                # extract features from the image
                image = get_image(file_path)
                preprocessed_image = test_datagen.random_transform(image)
                features = get_colors(preprocessed_image, 3)

                # append the features to the test_features list
                test_features.append(features)
                test_labels = np.concatenate((test_labels, np.array([folder_name])), axis=0)

# %%
# convert to a numpy array
test_features = np.array(test_features)

# %%
# print the shape of the TEST arrays
print("Test Features Shape:", test_features.shape)
print("Test Labels Shape:", test_labels.shape)
# Out:
# Test Features Shape: (40, 3, 3)
# Test Labels Shape: (40,)

# %% [markdown]
# # Model

# %% [markdown]
# ## RGB Model

# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
model = tf.keras.Sequential([
    layers.Conv1D(32, 1, activation='relu', input_shape=(3, 3)),
    layers.Conv1D(64, 1, activation='relu'),
    layers.Conv1D(128, 1, activation='relu'),
    
    layers.LSTM(32, return_sequences=True),
    layers.LSTM(64),
    
    layers.Flatten(),
    
    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(128, activation='relu'),
    
    layers.Dropout(0.5),
    
    layers.Dense(4, activation='softmax')
])

# %%
optimizer = tf.keras.optimizers.RMSprop()
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_21 (Conv1D)          (None, 3, 32)             128
#
#  conv1d_22 (Conv1D)          (None, 3, 64)             2112
#
#  conv1d_23 (Conv1D)          (None, 3, 128)            8320
#
#  lstm_14 (LSTM)              (None, 3, 32)             20608
#
#  lstm_15 (LSTM)              (None, 64)                24832
#
#  flatten_7 (Flatten)         (None, 64)                0
#
#  dense_28 (Dense)            (None, 64)                4160
#
#  dense_29 (Dense)            (None, 64)                4160
#
#  dense_30 (Dense)            (None, 128)               8320
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_31 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 73,156
# Trainable params: 73,156
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
import numpy as np
import tensorflow as tf

from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# %%
label_mapping = {"FN": 0, "-N": 1, "-P": 2, "-K": 3}

# %%
# map string labels to integer values
train_labels_mapped = np.array([label_mapping[label] for label in train_labels])
validation_labels_mapped = np.array([label_mapping[label] for label in validation_labels])
test_labels_mapped = np.array([label_mapping[label] for label in test_labels])

# one-hot encode the mapped labels
train_labels_one_hot = to_categorical(train_labels_mapped)
validation_labels_one_hot = to_categorical(validation_labels_mapped)
test_labels_one_hot = to_categorical(test_labels_mapped)

# %%
# define the EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = model.fit(
    train_features,
    train_labels_one_hot,
    epochs=400,
    batch_size=64,
    validation_data=(validation_features, validation_labels_one_hot),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/400
# 3/3 [==============================] - 8s 1s/step - loss: 1.3823 - accuracy: 0.2917 - val_loss: 1.3792 - val_accuracy: 0.3500
# Epoch 2/400
# 3/3 [==============================] - 0s 40ms/step - loss: 1.3686 - accuracy: 0.3750 - val_loss: 1.3754 - val_accuracy: 0.3167
# Epoch 3/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3716 - accuracy: 0.3403 - val_loss: 1.3575 - val_accuracy: 0.4000
# Epoch 4/400
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3351 - accuracy: 0.4444 - val_loss: 1.3626 - val_accuracy: 0.3000
# Epoch 5/400
# 3/3 [==============================] - 0s 40ms/step - loss: 1.3111 - accuracy: 0.4444 - val_loss: 1.2673 - val_accuracy: 0.5333
# Epoch 6/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2599 - accuracy: 0.4722 - val_loss: 1.2378 - val_accuracy: 0.4833
# Epoch 7/400
# 3/3 [==============================] - 0s 34ms/step - loss: 1.1952 - accuracy: 0.5278 - val_loss: 1.1657 - val_accuracy: 0.5500
# Epoch 8/400
# 3/3 [==============================] - 0s 40ms/step - loss: 1.1692 - accuracy: 0.4792 - val_loss: 1.1436 - val_accuracy: 0.5333
# Epoch 9/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2154 - accuracy: 0.4375 - val_loss: 1.0895 - val_accuracy: 0.5667
# Epoch 10/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0535 - accuracy: 0.5556 - val_loss: 1.3061 - val_accuracy: 0.2833
# Epoch 11/400
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2188 - accuracy: 0.3958 - val_loss: 1.1234 - val_accuracy: 0.6500
# Epoch 12/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0187 - accuracy: 0.6111 - val_loss: 1.1392 - val_accuracy: 0.5500
# Epoch 13/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0147 - accuracy: 0.5556 - val_loss: 1.1936 - val_accuracy: 0.4833
# Epoch 14/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2298 - accuracy: 0.3958 - val_loss: 1.0633 - val_accuracy: 0.5833
# Epoch 15/400
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0051 - accuracy: 0.5764 - val_loss: 1.1345 - val_accuracy: 0.5000
# Epoch 16/400
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0429 - accuracy: 0.5694 - val_loss: 1.0243 - val_accuracy: 0.5500
# Epoch 17/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.9962 - accuracy: 0.5833 - val_loss: 1.0730 - val_accuracy: 0.5500
# Epoch 18/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9573 - accuracy: 0.6181 - val_loss: 0.9706 - val_accuracy: 0.6000
# Epoch 19/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9343 - accuracy: 0.6042 - val_loss: 0.9558 - val_accuracy: 0.6500
# Epoch 20/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8797 - accuracy: 0.6806 - val_loss: 1.1203 - val_accuracy: 0.5167
# Epoch 21/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9781 - accuracy: 0.6181 - val_loss: 1.0736 - val_accuracy: 0.5667
# Epoch 22/400
# 3/3 [==============================] - 0s 41ms/step - loss: 0.9079 - accuracy: 0.6111 - val_loss: 0.9359 - val_accuracy: 0.7000
# Epoch 23/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8264 - accuracy: 0.6528 - val_loss: 0.8726 - val_accuracy: 0.7000
# Epoch 24/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8939 - accuracy: 0.6736 - val_loss: 0.9130 - val_accuracy: 0.6500
# Epoch 25/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8793 - accuracy: 0.6667 - val_loss: 1.1005 - val_accuracy: 0.5833
# Epoch 26/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9514 - accuracy: 0.6042 - val_loss: 1.1948 - val_accuracy: 0.4833
# Epoch 27/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9834 - accuracy: 0.5694 - val_loss: 0.8713 - val_accuracy: 0.7167
# Epoch 28/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7959 - accuracy: 0.6944 - val_loss: 0.8417 - val_accuracy: 0.6833
# Epoch 29/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7634 - accuracy: 0.6736 - val_loss: 1.0702 - val_accuracy: 0.5333
# Epoch 30/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.9023 - accuracy: 0.6458 - val_loss: 0.8960 - val_accuracy: 0.6500
# Epoch 31/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7502 - accuracy: 0.7361 - val_loss: 1.0492 - val_accuracy: 0.5167
# Epoch 32/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8637 - accuracy: 0.6528 - val_loss: 1.0834 - val_accuracy: 0.5833
# Epoch 33/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9543 - accuracy: 0.6319 - val_loss: 0.8728 - val_accuracy: 0.6833
# Epoch 34/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7918 - accuracy: 0.6458 - val_loss: 0.8313 - val_accuracy: 0.7000
# Epoch 35/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7536 - accuracy: 0.7222 - val_loss: 0.9952 - val_accuracy: 0.5000
# Epoch 36/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.8149 - accuracy: 0.6597 - val_loss: 1.1513 - val_accuracy: 0.4833
# Epoch 37/400
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0739 - accuracy: 0.5347 - val_loss: 0.9877 - val_accuracy: 0.6167
# Epoch 38/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8032 - accuracy: 0.6597 - val_loss: 0.9725 - val_accuracy: 0.5833
# Epoch 39/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8087 - accuracy: 0.7153 - val_loss: 0.8815 - val_accuracy: 0.6667
# Epoch 40/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7214 - accuracy: 0.6736 - val_loss: 0.9382 - val_accuracy: 0.6500
# Epoch 41/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8329 - accuracy: 0.6597 - val_loss: 0.8844 - val_accuracy: 0.6500
# Epoch 42/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.7851 - accuracy: 0.7014 - val_loss: 1.4419 - val_accuracy: 0.3833
# Epoch 43/400
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0494 - accuracy: 0.5417 - val_loss: 0.7939 - val_accuracy: 0.7333
# Epoch 44/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6983 - accuracy: 0.7361 - val_loss: 0.8069 - val_accuracy: 0.7167
# Epoch 45/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6771 - accuracy: 0.7500 - val_loss: 1.0618 - val_accuracy: 0.6167
# Epoch 46/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7631 - accuracy: 0.6944 - val_loss: 0.7820 - val_accuracy: 0.7000
# Epoch 47/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6137 - accuracy: 0.7708 - val_loss: 0.9999 - val_accuracy: 0.6000
# Epoch 48/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7113 - accuracy: 0.7153 - val_loss: 0.7753 - val_accuracy: 0.7500
# Epoch 49/400
# 3/3 [==============================] - 0s 42ms/step - loss: 0.7825 - accuracy: 0.6736 - val_loss: 1.0755 - val_accuracy: 0.6333
# Epoch 50/400
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8057 - accuracy: 0.6667 - val_loss: 0.8089 - val_accuracy: 0.7167
# Epoch 51/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6342 - accuracy: 0.7569 - val_loss: 0.9505 - val_accuracy: 0.5833
# Epoch 52/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6809 - accuracy: 0.7083 - val_loss: 0.7438 - val_accuracy: 0.7500
# Epoch 53/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6366 - accuracy: 0.7500 - val_loss: 0.9875 - val_accuracy: 0.5833
# Epoch 54/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7092 - accuracy: 0.6944 - val_loss: 1.0570 - val_accuracy: 0.6000
# Epoch 55/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6661 - accuracy: 0.7639 - val_loss: 0.9188 - val_accuracy: 0.6667
# Epoch 56/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6992 - accuracy: 0.7222 - val_loss: 0.7863 - val_accuracy: 0.7667
# Epoch 57/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.5905 - accuracy: 0.7708 - val_loss: 1.1197 - val_accuracy: 0.6167
# Epoch 58/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7468 - accuracy: 0.6944 - val_loss: 1.0609 - val_accuracy: 0.6000
# Epoch 59/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7690 - accuracy: 0.7014 - val_loss: 0.8964 - val_accuracy: 0.6833
# Epoch 60/400
# 3/3 [==============================] - 0s 42ms/step - loss: 0.8698 - accuracy: 0.6319 - val_loss: 0.9317 - val_accuracy: 0.7000
# Epoch 61/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6328 - accuracy: 0.7847 - val_loss: 0.8242 - val_accuracy: 0.7000
# Epoch 62/400
# 3/3 [==============================] - 0s 42ms/step - loss: 0.6424 - accuracy: 0.7431 - val_loss: 0.9083 - val_accuracy: 0.6333

# %%
loss, accuracy = model.evaluate(test_features, test_labels_one_hot)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5709 - accuracy: 0.7500
# Loss: 0.5709426403045654
# Accuracy: 0.75

# %% [markdown]
# ## Evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report

# %%
# convert predicted probabilities to labels
y_pred_probs = model.predict(test_features)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
# convert test_labels to numeric labels
numeric_labels = np.array([label_mapping[label] for label in test_labels])

# %%
# calculate confusion matrix
confusion = confusion_matrix(numeric_labels, y_pred_labels)

# %%
# visualize the confusion matrix
plt.figure(figsize=(8, 8))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# generate classification report
report = classification_report(numeric_labels, y_pred_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.71      1.00      0.83        10
#            2       0.67      0.80      0.73        10
#            3       0.80      0.40      0.53        10
#
#     accuracy                           0.75        40
#    macro avg       0.77      0.75      0.73        40
# weighted avg       0.77      0.75      0.73        40

# %%
def plot_training_history(history):
    # get the training and validation metrics
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # plot accuracy
    plt.figure(figsize=(6, 4))
    plt.plot(accuracy, 'g', label='Training Accuracy')
    plt.plot(val_accuracy, 'b', label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')
    plt.show()

    # plot loss
    plt.figure(figsize=(6, 4))
    plt.plot(loss, 'g', label='Training Loss')
    plt.plot(val_loss, 'b', label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

# %%
plot_training_history(history)

# %% [markdown]
# # Predict and Recommendation

# %%
from PIL import Image

# %%
def get_input(image_path):
    image = get_image(image_path)
    image = get_colors(image, 3)
    image = np.expand_dims(image, axis=0)  # an extra dimension for batch size
    return image

# %%
# predict function for inference
def predict(model, img):
    predictions = model.predict(img)
    predicted_class = class_names[np.argmax(predictions[0])]
    
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
def generate_custom_paragraph(predicted_label):

    default = '\nSaran lainnya: \n 1. Pertahankan pH larutan nutrisi hidroponik (antara 5.5 hingga 6.5). \n 2. Pastikan sistem hidroponik memiliki sirkulasi air yang baik \n 3. Gunakan sistem filtrasi air jika diperlukan.'
    # Define a mapping of labels to custom paragraphs
    mapping = { # tinggal revisi paragraf
        'FN': 'Selada yang  memiliki cukup nutrisi dapat mengalami pertumbuhan yang baik dan warna daun yang sehat. \n Dalam kondisi ini, tidak terdapat kekurangan nutrisi spesifik yang perlu diatasi. \n' + default,
        '-N': 'Selada yang kekurangan nitrogen dapat mengalami pertumbuhan terhambat, warna daun kekuningan, \n serta kualitas tanaman yang rendah. Untuk mengatasi masalah ini, disarankan untuk meningkatkan \n pemupukan nitrogen menggunakan pupuk yang kaya akan nutrisi tersebut. \n 1. Pupuk ZA Petro \n 2. KNO3 Crystal \n 3. Mutiara Sprinter Pupuk NPK 20-10-10 \n' + default,
        '-P': 'Selada yang kekurangan fosfor dapat mengalami pertumbuhan terhambat, perkembangan akar yang terganggu, \n warna daun yang keunguan dan pucat, serta kualitas tanaman yang rendah. Untuk mengatasi masalah ini, \n disarankan untuk meningkatkan pemupukan fosfor menggunakan pupuk yang kaya akan nutrisi tersebut. \n 1. Pupuk DAP ULTRADAP pak tani \n 2. Pupuk MAP MerokeMAP \n 3. Pupuk TSP MerokeTSP \n' + default,
        '-K': 'Selada yang kekurangan kalium dapat mengalami pertumbuhan terhambat, perkembangan akar yang terganggu, \n warna daun kecoklatan, serta resistensi terhadap penyakit yang rendah. Untuk mengatasi masalah ini, \n disarankan untuk meningkatkan pemupukan menggunakan pupuk yang kaya akan nutrisi tersebut. \n 1. Pupuk KNO3 Crystal \n 2. Pupuk KCL MerokeMOP \n 3. Pupuk ZK Cap Goldenmax \n' + default,
    }
    
    # Get the custom paragraph based on the predicted label
    custom_paragraph = mapping.get(predicted_label, 'Tidak ada rekomendasi untuk saat ini')
    
    return custom_paragraph

# %%
# get a sample image
image = get_image('/content/drive/MyDrive/capstone/dataset/lettuce/-P/-P (38).png')

# predict the image
input_image = get_input(image)
predicted_class, confidence = predict(model, input_image)

# convert predicted class
label_mapping = {"FN": "Fully Nutritional", "-N": "Nitrogen Deficiency", "-P": "Phosporus Deficiency", "-K": "Kalium Deficiency"}
predicted_class_mapped = label_mapping[predicted_class]

plt.imshow(image)  
plt.title(f"Diagnosis: {predicted_class_mapped}\n Confidence: {confidence}%\n\n Notes: {generate_custom_paragraph(predicted_class)}")    
plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 50ms/step
# (-0.5, 223.5, 223.5, -0.5)

# %% [markdown]
# # Save Keras Model

# %%
import tensorflow as tf

# %%
# saved to .h5 format
model.save(base_dir + '/lettuce_model.h5')
model = tf.keras.models.load_model(base_dir + '/lettuce_model.h5')

# %%
# saved to tensorflow
export_dir = base_dir + '/saved_model_capstone'
tf.saved_model.save(model, export_dir=export_dir)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla, lstm_cell_18_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.

# %%
mode = "" 

if mode == 'Storage':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_SIZE
elif mode == 'Speed':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_LATENCY
else:
    optimization = tf.lite.Optimize.DEFAULT

# %%
# convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
converter.optimizations = [optimization]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]

# disable experimental lowering of tensor list ops
converter.experimental_lower_tensor_list_ops = False

tflite_model = converter.convert()

# %%
# save the TensorFlow Lite model
with open('lettuce_model.tflite', 'wb') as f:
    f.write(tflite_model)
